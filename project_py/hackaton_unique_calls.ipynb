# %%
import pandas as pd
import pickle
data = pd.read_pickle("cdr_clean_no_duplicates.pkl")

# %%
data['dateOrigin'] = data['dateTimeOrigination'].dt.date

# %%
data.groupby(['globalCallID_callManagerId', 'globalCallID_callId', 'dateOrigin']).count()
# Out:
#                                                            origLegCallIdentifier  \
# globalCallID_callManagerId globalCallID_callId dateOrigin
# 1                          1                   2024-01-16                      2
#                            2                   2024-01-16                      2
#                            3                   2024-01-16                      1
#                            4                   2024-01-16                      2
#                            5                   2024-01-16                      2
# ...                                                                          ...
# 4                          6319773             2024-03-29                      2
#                            6319775             2024-03-30                      1
#                            6319776             2024-03-30                      1
#                            6319777             2024-03-30                      1
# ...

# %%
data['unique_call_id'] = data.groupby(['globalCallID_callManagerId', 'globalCallID_callId', 'dateOrigin']).ngroup()

# %%
data['unique_call_id'].max()
# Out:
# np.int64(2781786)

# %%
data = data.drop(columns=['dateOrigin'])

# %%
data
# Out:
#          globalCallID_callManagerId  globalCallID_callId  \
# 0                                 1             16615182
# 1                                 1             16615183
# 2                                 1             16615184
# 3                                 1             16615185
# 4                                 1             16615186
# ...                             ...                  ...
# 3805581                           4              6319773
# 3805582                           4              6319775
# 3805583                           4              6319776
# 3805584                           4              6319777
# 3805585                           4              6319778
#
#          origLegCallIdentifier dateTimeOrigination callingPartyNumber  \
# 0                     19957562 2024-01-01 01:20:13       437734693017
# 1                     19957564 2024-01-01 03:08:00       436618449646
# ...

# %%
data.to_pickle('cdr_clean_unique_calls.pkl')
