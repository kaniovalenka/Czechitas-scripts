# %%
import pandas as pd
import pickle
data = pd.read_pickle("cdr_clean.pkl")

# %%
data_nopkid = data.drop(columns=['pkid'])

# %%
rows_to_keep = ~data_nopkid.duplicated()

# %%
rows_to_keep.sum()
# Out:
# np.int64(3805585)

# %%
data.shape
# Out:
# (3805586, 25)

# %%
data_deduplicated = data.loc[rows_to_keep]

# %%
data_deduplicated[data_deduplicated['globalCallID_callManagerId'] == 0]
# Out:
#          globalCallID_callManagerId  globalCallID_callId  \
# 2978251                           0                    0
# 2978252                           0                    0
#
#          origLegCallIdentifier dateTimeOrigination callingPartyNumber  \
# 2978251               50409300                 NaT               <NA>
# 2978252               50409302                 NaT               <NA>
#
#          origCause_value  destLegIdentifier originalCalledPartyNumber  \
# 2978251               41           50409301                      <NA>
# 2978252               41           50409303                      <NA>
#
#         finalCalledPartyNumber  destCause_value  ... origDeviceName  \
# 2978251                   <NA>                0  ...    10.1.52.233
# 2978252                   <NA>                0  ...     10.5.3.233
#
#         destDeviceName origCallTerminationOnBehalfOf  \
# 2978251           <NA>                            12
# ...

# %%
data_deduplicated = data_deduplicated[data_deduplicated['globalCallID_callManagerId'] > 0]

# %%
data_deduplicated.to_pickle('cdr_clean_no_duplicates.pkl')
