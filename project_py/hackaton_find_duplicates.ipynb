# %%
import pandas as pd
import pickle
data = pd.read_pickle("cdr_clean.pkl")

# %%
data = data.drop(columns=['pkid'])

# %%
data.shape[0]
# Out:
# 3805586

# %%
type(data.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
counts = data.groupby(by=list(data.columns)).count()

# %%
counts.head()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
data[data.duplicated()==True]
# Out:
#          globalCallID_callManagerId  globalCallID_callId  \
# 3536363                           1               363534
#
#          origLegCallIdentifier dateTimeOrigination callingPartyNumber  \
# 3536363               67747431 2024-02-20 13:05:01      0046133053414
#
#          origCause_value  destLegIdentifier originalCalledPartyNumber  \
# 3536363                0           67747687             +437134539429
#
#         finalCalledPartyNumber  destCause_value  ...   origDeviceName  \
# 3536363          +437134539429               27  ...  BK044_000_Tele2
#
#         destDeviceName origCallTerminationOnBehalfOf  \
# 3536363     CSFC29KMCL                            10
#
#          destCallTerminationOnBehalfOf origCalledPartyRedirectOnBehalfOf  \
# 3536363                             12                                 0
#
#         lastRedirectRedirectOnBehalfOf  origCalledPartyRedirectReason  \
# 3536363                             10                              0
#
# ...

# %%
data[(data['globalCallID_callId']==363534) & (data['origLegCallIdentifier'] == 67747431)]
# Out:
#          globalCallID_callManagerId  globalCallID_callId  \
# 3536307                           1               363534
# 3536362                           1               363534
# 3536363                           1               363534
# 3536364                           1               363534
# 3536398                           1               363534
# 3536464                           1               363534
#
#          origLegCallIdentifier dateTimeOrigination callingPartyNumber  \
# 3536307               67747431 2024-02-20 13:02:49      0046133053414
# 3536362               67747431 2024-02-20 13:05:01      0046133053414
# 3536363               67747431 2024-02-20 13:05:01      0046133053414
# 3536364               67747431 2024-02-20 13:05:01      0046133053414
# 3536398               67747431 2024-02-20 13:05:01      0046133053414
# 3536464               67747431 2024-02-20 13:07:00      0046133053414
#
# ...

# %%
data_complete = pd.read_pickle(r"C:\Users\Lenka\Documents\data analýza\DA\PROJEKT\Hovory\zakl pandas\Staredata\all_cdr_files_in_one.pkl")

# %%
data_complete = data_complete.drop(columns=['pkid'])
# Out:
# C:\Users\Lenka\AppData\Local\Temp\ipykernel_19488\4061093556.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   data_complete = data_complete.drop(columns=['pkid'])

# %%
data_complete[data_complete.duplicated()]
# Out:
#    cdrRecordType globalCallID_callManagerId globalCallID_callId  \
#          INTEGER                    INTEGER             INTEGER
# 71             1                          1              363534
#
#    origLegCallIdentifier dateTimeOrigination origNodeId  origSpan  origIpAddr  \
#                  INTEGER             INTEGER    INTEGER   INTEGER     INTEGER
# 71              67747431          1708434301          4  67747431  1387659530
#
#    callingPartyNumber callingPartyUnicodeLoginUserID  ...  \
#           VARCHAR(50)                   VARCHAR(128)  ...
# 71      0046133053414                            NaN  ...
#
#    destMobileCallDuration mobileCallType originalCalledPartyPattern  \
#                   INTEGER        INTEGER                VARCHAR(50)
# 71                      0              0              +437134539429
#
#    finalCalledPartyPattern lastRedirectingPartyPattern huntPilotPattern  \
#                VARCHAR(50)                 VARCHAR(50)      VARCHAR(50)
# ...

# %%
data_complete.shape
# Out:
# (3805586, 133)
