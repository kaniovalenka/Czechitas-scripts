# %%
import pandas as pd
import pickle
data = pd.read_pickle(r"..\cdr_clean_unique_calls.pkl")

# %%
start_b00 = data['callingPartyNumber'].str.startswith('b00', na=False)
pocet = start_b00.sum()
print(f"Počet hodnot zacinajicich na 'b00': {pocet}")
# Out:
# Počet hodnot zacinajicich na 'b00': 542748

# %%
data_no_b00 = data[~data['callingPartyNumber'].str.startswith('b00', na=False)]
data_no_b00.to_pickle('cdr_clean_unique_calls_NOb00.pkl')

# %%
data = pd.read_pickle('cdr_clean_unique_calls_NOb00.pkl')

# %%
start_b00 = data['callingPartyNumber'].str.startswith('b00', na=False)
pocet = start_b00.sum()
print(f"Počet hodnot zacinajicich na 'b00': {pocet}")
# Out:
# Počet hodnot zacinajicich na 'b00': 0

# %%
data.shape
# Out:
# (3262835, 26)

# %%
data.head()
# Out:
#    globalCallID_callManagerId  globalCallID_callId  origLegCallIdentifier  \
# 0                           1             16615182               19957562
# 1                           1             16615183               19957564
# 2                           1             16615184               19957566
# 3                           1             16615185               19957568
# 4                           1             16615186               19957570
#
#   dateTimeOrigination callingPartyNumber  origCause_value  destLegIdentifier  \
# 0 2024-01-01 01:20:13       437734693017               16           19957563
# 1 2024-01-01 03:08:00       436618449646               16           19957565
# 2 2024-01-01 05:07:47       436359992566               16           19957567
# 3 2024-01-01 05:41:29               9999               16           19957569
# 4 2024-01-01 06:07:14       433496903750                0           19957571
#
# ...
